# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Df3')

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df.plot.scatter(x='a', y='b', figsize=(12,3), s=50, c='red')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.style.use('ggplot')
df['a'].plot.hist(alpha=0.5,bins=25)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['a', 'b']].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['d'].plot.density(lw=5, ls="--")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.iloc[0:30].plot.area(alpha=0.6)
# Out:
# <AxesSubplot:>

# %%
df.iloc[0:30].plot.area(alpha=0.6)
plt.legend(loc='center right')
